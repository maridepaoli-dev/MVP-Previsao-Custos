# %% [markdown]
# <a href="https://colab.research.google.com/github/maridepaoli-dev/MVP-Previsao-Custos/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/maridepaoli-dev/MVP-Previsao-Custos/main/BaseOperadora.xlsx"

df = pd.read_excel(url)

df.head()

print(df.columns)
# Out:
# Index(['DATA', 'REG_ANS', 'CD_CONTA_CONTABIL', 'DESCRICAO', 'VL_SALDO_FINAL'], dtype='object')
